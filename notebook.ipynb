# %% [markdown]
# # Predicting Booking Cancellations: Hotel Reservations

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import pycountry as pc
import pycountry_convert as pcc

# %% [markdown]
# ## Loading and Exploring the Dataset

# %%
# Read csv file and create a DataFrame
df = pd.read_csv('dataset/hotel_bookings_extra_columns.csv')

# %%
# Inspect the dataset shaoe
print(f'Number of rows: {df.shape[0]} \nNumber of columns: {df.shape[1]}')
# Out:
# Number of rows: 119390
# Number of columns: 36

# %%
pd.set_option('display.max_columns', None)

# %%
# Show the first 5 rows of the DataFrame
df.head(20)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# 15  Resort Hotel            0         68               2015
# 16  Resort Hotel            0         37               2015
# 17  Resort Hotel            0         12               2015
# 18  Resort Hotel            0          0               2015
# 19  Resort Hotel            0          7               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                July                        27                          1
# 1                July                        27                          1
# 2                July                        27                          1
# 3                July                        27                          1
# 4                July                        27                          1
# 5                July                        27                          1
# 6                July                        27                          1
# 7                July                        27                          1
# 8                July                        27                          1
# 9                July                        27                          1
# 10               July                        27                          1
# 11               July                        27                          1
# 12               July                        27                          1
# 13               July                        27                          1
# 14               July                        27                          1
# 15               July                        27                          1
# 16               July                        27                          1
# 17               July                        27                          1
# 18               July                        27                          1
# 19               July                        27                          1
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                         0                     0       2       0.0       0
# 1                         0                     0       2       0.0       0
# 2                         0                     1       1       0.0       0
# 3                         0                     1       1       0.0       0
# 4                         0                     2       2       0.0       0
# 5                         0                     2       2       0.0       0
# 6                         0                     2       2       0.0       0
# 7                         0                     2       2       0.0       0
# 8                         0                     3       2       0.0       0
# 9                         0                     3       2       0.0       0
# 10                        0                     4       2       0.0       0
# 11                        0                     4       2       0.0       0
# 12                        0                     4       2       0.0       0
# 13                        0                     4       2       1.0       0
# 14                        0                     4       2       0.0       0
# 15                        0                     4       2       0.0       0
# 16                        0                     4       2       0.0       0
# 17                        0                     1       2       0.0       0
# 18                        0                     1       2       0.0       0
# 19                        0                     4       2       0.0       0
#
#    meal country market_segment distribution_channel  is_repeated_guest  \
# 0    BB     PRT         Direct               Direct                  0
# 1    BB     PRT         Direct               Direct                  0
# 2    BB     GBR         Direct               Direct                  0
# 3    BB     GBR      Corporate            Corporate                  0
# 4    BB     GBR      Online TA                TA/TO                  0
# 5    BB     GBR      Online TA                TA/TO                  0
# 6    BB     PRT         Direct               Direct                  0
# 7    FB     PRT         Direct               Direct                  0
# 8    BB     PRT      Online TA                TA/TO                  0
# 9    HB     PRT  Offline TA/TO                TA/TO                  0
# 10   BB     PRT      Online TA                TA/TO                  0
# 11   HB     PRT      Online TA                TA/TO                  0
# 12   BB     USA      Online TA                TA/TO                  0
# 13   HB     ESP      Online TA                TA/TO                  0
# 14   BB     PRT      Online TA                TA/TO                  0
# 15   BB     IRL      Online TA                TA/TO                  0
# 16   BB     PRT  Offline TA/TO                TA/TO                  0
# 17   BB     IRL      Online TA                TA/TO                  0
# 18   BB     FRA      Corporate            Corporate                  0
# 19   BB     GBR         Direct               Direct                  0
#
#     previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                        0                               0                  C
# 1                        0                               0                  C
# 2                        0                               0                  A
# 3                        0                               0                  A
# 4                        0                               0                  A
# 5                        0                               0                  A
# 6                        0                               0                  C
# 7                        0                               0                  C
# 8                        0                               0                  A
# 9                        0                               0                  D
# 10                       0                               0                  E
# 11                       0                               0                  D
# 12                       0                               0                  D
# 13                       0                               0                  G
# 14                       0                               0                  E
# 15                       0                               0                  D
# 16                       0                               0                  E
# 17                       0                               0                  A
# 18                       0                               0                  A
# 19                       0                               0                  G
#
#    assigned_room_type  booking_changes deposit_type  agent  company  \
# 0                   C                3   No Deposit    NaN      NaN
# 1                   C                4   No Deposit    NaN      NaN
# 2                   C                0   No Deposit    NaN      NaN
# 3                   A                0   No Deposit  304.0      NaN
# 4                   A                0   No Deposit  240.0      NaN
# 5                   A                0   No Deposit  240.0      NaN
# 6                   C                0   No Deposit    NaN      NaN
# 7                   C                0   No Deposit  303.0      NaN
# 8                   A                0   No Deposit  240.0      NaN
# 9                   D                0   No Deposit   15.0      NaN
# 10                  E                0   No Deposit  240.0      NaN
# 11                  D                0   No Deposit  240.0      NaN
# 12                  E                0   No Deposit  240.0      NaN
# 13                  G                1   No Deposit  241.0      NaN
# 14                  E                0   No Deposit  241.0      NaN
# 15                  E                0   No Deposit  240.0      NaN
# 16                  E                0   No Deposit    8.0      NaN
# 17                  E                0   No Deposit  240.0      NaN
# 18                  G                0   No Deposit    NaN    110.0
# 19                  G                0   No Deposit  250.0      NaN
#
#     days_in_waiting_list customer_type     adr  required_car_parking_spaces  \
# 0                      0     Transient    0.00                            0
# 1                      0     Transient    0.00                            0
# 2                      0     Transient   75.00                            0
# 3                      0     Transient   75.00                            0
# 4                      0     Transient   98.00                            0
# 5                      0     Transient   98.00                            0
# 6                      0     Transient  107.00                            0
# 7                      0     Transient  103.00                            0
# 8                      0     Transient   82.00                            0
# 9                      0     Transient  105.50                            0
# 10                     0     Transient  123.00                            0
# 11                     0     Transient  145.00                            0
# 12                     0     Transient   97.00                            0
# 13                     0     Transient  154.77                            0
# 14                     0     Transient   94.71                            0
# 15                     0     Transient   97.00                            0
# 16                     0      Contract   97.50                            0
# 17                     0     Transient   88.20                            0
# 18                     0     Transient  107.42                            0
# 19                     0     Transient  153.00                            0
#
#     total_of_special_requests reservation_status reservation_status_date  \
# 0                           0          Check-Out              2015-07-01
# 1                           0          Check-Out              2015-07-01
# 2                           0          Check-Out              2015-07-02
# 3                           0          Check-Out              2015-07-02
# 4                           1          Check-Out              2015-07-03
# 5                           1          Check-Out              2015-07-03
# 6                           0          Check-Out              2015-07-03
# 7                           1          Check-Out              2015-07-03
# 8                           1           Canceled              2015-05-06
# 9                           0           Canceled              2015-04-22
# 10                          0           Canceled              2015-06-23
# 11                          0          Check-Out              2015-07-05
# 12                          3          Check-Out              2015-07-05
# 13                          1          Check-Out              2015-07-05
# 14                          0          Check-Out              2015-07-05
# 15                          3          Check-Out              2015-07-05
# 16                          0          Check-Out              2015-07-05
# 17                          0          Check-Out              2015-07-02
# 18                          0          Check-Out              2015-07-02
# 19                          1          Check-Out              2015-07-05
#
#                      name                         email  phone-number  \
# 0           Ernest Barnes   Ernest.Barnes31@outlook.com  669-792-1661
# 1            Andrea Baker        Andrea_Baker94@aol.com  858-637-6955
# 2          Rebecca Parker    Rebecca_Parker@comcast.net  652-885-2745
# 3            Laura Murray             Laura_M@gmail.com  364-656-8427
# 4             Linda Hines            LHines@verizon.com  713-226-5883
# 5        Jasmine Fletcher       JFletcher43@xfinity.com  190-271-6743
# 6            Dylan Rangel      Rangel.Dylan@comcast.net  420-332-5209
# 7           William Velez        Velez_William@mail.com  286-669-4333
# 8           Steven Murphy       Steven.Murphy54@aol.com  341-726-5787
# 9           Michael Moore    MichaelMoore81@outlook.com  316-648-6176
# 10  Priscilla Collins PhD       PhD.Priscilla74@att.com  833-887-7898
# 11           Laurie Smith          Smith.Laurie@att.com  804-383-4080
# 12           Casey Thomas         Casey_T78@outlook.com  211-071-2173
# 13        Rachel Friedman       Rachel.F@protonmail.com  435-075-8409
# 14          Edward Torres             Edward.T@zoho.com  790-746-7471
# 15          Samuel Zavala   Zavala_Samuel46@xfinity.com  649-384-5387
# 16      Dr. Victor Martin         Dr.Martin@xfinity.com  331-430-8824
# 17               Sara Lee            Sara.L@hotmail.com  573-306-9938
# 18       Curtis Rodriguez        CRodriguez@verizon.com  466-424-2102
# 19      Stephanie Schmidt  StephanieSchmidt@hotmail.com  896-642-1049
#
#          credit_card
# 0   ************4322
# 1   ************9157
# 2   ************3734
# 3   ************5677
# 4   ************5498
# 5   ************9263
# 6   ************6994
# 7   ************8729
# 8   ************3639
# 9   ************9190
# 10  ************4642
# 11  ************5450
# 12  ************8518
# 13  ************9767
# 14  ************7719
# 15  ************7612
# 16  ************6279
# 17  ************8950
# 18  ************1179
# 19  ************1110

# %%
# Show information about columns and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
#  32  name                            119390 non-null  object
#  33  email                           119390 non-null  object
#  34  phone-number                    119390 non-null  object
#  35  credit_card                     119390 non-null  object
# dtypes: float64(4), int64(16), object(16)
# memory usage: 32.8+ MB

# %%
# Inspect every feature and add categorical attributes to a list
cat_col = ['hotel','arrival_date_year','arrival_date_month','meal','country','market_segment','distribution_channel','reserved_room_type',
          'assigned_room_type','deposit_type','agent','company','customer_type','reservation_status']

# %%
# Add boolean features to a list
bool_col = ['is_canceled','is_repeated_guest']

# %%
# Convert every categorical attribute's datatype to 'object'
for i in cat_col:
    df[i] = df[i].astype(object)

# %%
# Convert boolean attribute's datatype to 'bool'
for i in bool_col:
    df[i] = df[i].astype(bool)

# %%
# Show summary statistics for numerical values, transposed for better readability
df.describe().T
# Out:
#                                    count        mean         std   min    25%  \
# lead_time                       119390.0  104.011416  106.863097  0.00  18.00
# arrival_date_week_number        119390.0   27.165173   13.605138  1.00  16.00
# arrival_date_day_of_month       119390.0   15.798241    8.780829  1.00   8.00
# stays_in_weekend_nights         119390.0    0.927599    0.998613  0.00   0.00
# stays_in_week_nights            119390.0    2.500302    1.908286  0.00   1.00
# adults                          119390.0    1.856403    0.579261  0.00   2.00
# children                        119386.0    0.103890    0.398561  0.00   0.00
# babies                          119390.0    0.007949    0.097436  0.00   0.00
# previous_cancellations          119390.0    0.087118    0.844336  0.00   0.00
# previous_bookings_not_canceled  119390.0    0.137097    1.497437  0.00   0.00
# booking_changes                 119390.0    0.221124    0.652306  0.00   0.00
# days_in_waiting_list            119390.0    2.321149   17.594721  0.00   0.00
# adr                             119390.0  101.831122   50.535790 -6.38  69.29
# required_car_parking_spaces     119390.0    0.062518    0.245291  0.00   0.00
# total_of_special_requests       119390.0    0.571363    0.792798  0.00   0.00
#
#                                    50%    75%     max
# lead_time                       69.000  160.0   737.0
# arrival_date_week_number        28.000   38.0    53.0
# arrival_date_day_of_month       16.000   23.0    31.0
# stays_in_weekend_nights          1.000    2.0    19.0
# stays_in_week_nights             2.000    3.0    50.0
# adults                           2.000    2.0    55.0
# children                         0.000    0.0    10.0
# babies                           0.000    0.0    10.0
# previous_cancellations           0.000    0.0    26.0
# previous_bookings_not_canceled   0.000    0.0    72.0
# booking_changes                  0.000    0.0    21.0
# days_in_waiting_list             0.000    0.0   391.0
# adr                             94.575  126.0  5400.0
# required_car_parking_spaces      0.000    0.0     8.0
# total_of_special_requests        0.000    1.0     5.0

# %%
# Show summary statistics of categorical columns, transposed
df.describe(include='object').T
# Out:
#                             count  unique                  top     freq
# hotel                      119390       2           City Hotel    79330
# arrival_date_year          119390       3                 2016    56707
# arrival_date_month         119390      12               August    13877
# meal                       119390       5                   BB    92310
# country                    118902     177                  PRT    48590
# market_segment             119390       8            Online TA    56477
# distribution_channel       119390       5                TA/TO    97870
# reserved_room_type         119390      10                    A    85994
# assigned_room_type         119390      12                    A    74053
# deposit_type               119390       3           No Deposit   104641
# agent                    103050.0   333.0                  9.0  31961.0
# company                    6797.0   352.0                 40.0    927.0
# customer_type              119390       4            Transient    89613
# reservation_status         119390       3            Check-Out    75166
# reservation_status_date    119390     926           2015-10-21     1461
# name                       119390   81503      Michael Johnson       48
# email                      119390  115889  Michael.C@gmail.com        6
# phone-number               119390  119390         669-792-1661        1
# credit_card                119390    9000     ************4923       28

# %%
# Show fields that contain null values and the number of null values
null_sum = df.isna().sum()
null_sum = null_sum[null_sum>0]
null_sum
# Out:
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64

# %%
# Check if there are duplicated rows in the dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Handling Null Values

# %%
# Calculate and display the rate of null values to the number of rows in the dataset for each column that contains null values
null_sum / df.shape[0] * 100
# Out:
# children     0.003350
# country      0.408744
# agent       13.686238
# company     94.306893
# dtype: float64

# %% [markdown]
# Since 'children' and 'country' columns' rate is so low, the rows containing null values in these 2 columns will be dropped.

# %%
# Drop any column that has null value in these 2 columns
df = df.dropna(subset = ['children','country'])

# %% [markdown]
# Due to their high rate of null values and irrelevancy to the target value, remaining 2 features will be dropped completely.

# %%
# Drop 'agent' and 'company' features
df = df.drop(labels = ['agent','company'], axis=1)

# %%
# Check to see if there are any null values remained
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# name                              0
# email                             0
# phone-number                      0
# credit_card                       0
# dtype: int64

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# In the dataset, 4 features include personal information about customers, which are not relevant to our target variable. Those 4 features will be dropped.

# %%
# Drop columns that contain personal information
df = df.drop(['name','email','phone-number','credit_card'],axis=1)

# %% [markdown]
# There are 2 attributes that give information about the target variable 'is_canceled' which causes data leakage. To prevent this from happening, following attributes will be dropped:
# - reservation_status
# - reservation_status_date

# %%
# Drop the columns that cause data leakage
df = df.drop(['reservation_status','reservation_status_date'],axis=1)

# %% [markdown]
# Checking the unique values in each feature is useful to detect any attributes with high cardinality and determining if a new feature can be created.

# %%
# Show the number of unique values of categorical features
df.select_dtypes(include='object').nunique().sort_values(ascending=False)
# Out:
# country                 177
# arrival_date_month       12
# assigned_room_type       12
# reserved_room_type       10
# market_segment            7
# meal                      5
# distribution_channel      5
# customer_type             4
# arrival_date_year         3
# deposit_type              3
# hotel                     2
# dtype: int64

# %% [markdown]
# The 'country' feature has high-cardinality. The best practice is to group it into a 'continent' feature to reduce the cardinality.

# %% [markdown]
# #### Creating 'continent' Feature

# %% [markdown]
# For creating 'continent' feature, 'pycountry' and 'pycountry_convert' libraries will be used.
# Our dataset contains 3-digit country codes (ISO 3166-1 alpha-3) as the 'country' feature. A new feature using 2-digit country codes (ISO 3166-1 alpha-2) needs to be created.

# %%
# Some adjustments to correct irregularities in the dataset
# Convert 'CN' values to 'CHN' which is country code of China
df.loc[df['country'] == 'CN', 'country'] = 'CHN'

# Drop columns with the country code 'TMP', which is not a standard code defined in ISO 3166
df = df.query('country not in ("TMP")')

# %%
# Create 'country_a2' feature, 2-digit country codes
df['country_a2'] = list(map(lambda x: pcc.country_alpha3_to_country_alpha2(x), df['country']))

# %%
# Show the last 5 rows to check the new column visually
df[['country','country_a2']].tail()
# Out:
#        country country_a2
# 119385     BEL         BE
# 119386     FRA         FR
# 119387     DEU         DE
# 119388     GBR         GB
# 119389     DEU         DE

# %%
# Drop columns with the country codes 'UM','AQ' and 'TF' which are not standard codes
df = df.query('country_a2 not in ("UM","AQ","TF")')

# %%
# Create 'continent' feature using 'pycountry_convert' library
df['continent'] = list(map(lambda x: pcc.country_alpha2_to_continent_code(x), df['country_a2']))

# %%
# Show the last 5 rows
df[['country','country_a2','continent']].tail()
# Out:
#        country country_a2 continent
# 119385     BEL         BE        EU
# 119386     FRA         FR        EU
# 119387     DEU         DE        EU
# 119388     GBR         GB        EU
# 119389     DEU         DE        EU

# %%
# Display the number of bookings for each continent
df['continent'].value_counts()
# Out:
# continent
# EU    107822
# AS      4468
# SA      2708
# NA      2274
# AF      1113
# OC       506
# Name: count, dtype: int64

# %% [markdown]
# By grouping the countries into their respective continents, the cardinality of the feature is decreased.
# This will prevent the model from overfitting to our training dataset and enhance its ability to generalize to unseen data.

# %%
df = df.drop(['country','country_a2'],axis = 1)

# %% [markdown]
# #### Creating 'is_room_type_matched' Feature

# %% [markdown]
# Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request.
# This feature is added to reflect whether the customer is assigned to their requested room type.

# %%
# Add the new boolean feature based on the condition
df['is_room_type_matched'] = df['reserved_room_type'] == df['assigned_room_type']

# %%
# Check the dtype of the new feature
df['is_room_type_matched'].dtype
# Out:
# dtype('bool')

# %%
# Drop both the features 'reserved_room_type' and 'assigned_room_type'
df = df.drop(['reserved_room_type','assigned_room_type'],axis =1)

# %% [markdown]
# #### Creating 'meal_ordinal' Feature

# %% [markdown]
# The 'meal' feature includes the meal packages that customers choose while making bookings.
# The meanings of the codes in the dataset are as follows:
#
# Undefined/SC – no meal package\
# BB – Bed & Breakfast\
# HB – Half board (breakfast and one other meal)\
# FB – Full board (breakfast, lunch and dinner)
#
# Thus, an ordinal feature can be derived from this feature with values ranging from 0 to 3, where 0 represents the cheapest option and 3 the most expensive.

# %%
# Display the unique values and their number of occurence in the dataset
df['meal'].value_counts()
# Out:
# meal
# BB           91858
# HB           14434
# SC           10636
# Undefined     1165
# FB             798
# Name: count, dtype: int64

# %%
# Create a dictionary to map categorical meal options to ordinal values
meal_dict = {'Undefined':0, 'SC':0, 'BB':1, 'HB':2, 'FB':3}

# %%
# Use meal_dict dictionary to map categorical values to integers
df['meal_ordinal'] = df['meal'].map(meal_dict)

# %%
# Check the dtype
print(df['meal_ordinal'].dtype)
# Out:
# int64

# %%
# Drop the meal feature
df = df.drop('meal',axis =1)

# %% [markdown]
# #### Creating 'season' Feature

# %% [markdown]
# According to Travel+Leisure, a well known travel magazine, Portugal's tourism seasons fall into 3 categories:\
# (Note that both hotels included in the dataset are located in Lisbon, Portugal.)
#
# High Season: June through August\
# Shoulder Season: September to November; April to June\
# Low Season: December to April

# %%
# Count and display the number of bookings in each month
df['arrival_date_month'].value_counts()
# Out:
# arrival_date_month
# August       13852
# July         12627
# May          11778
# October      11094
# April        11045
# June         10926
# September    10467
# March         9739
# February      8012
# November      6752
# December      6726
# January       5873
# Name: count, dtype: int64

# %%
# Create the function to map months to seasons
def month_to_season(month):
    """ Convert the month name to tourism season."""
    
    if month in ['June','July','August']:
        return 'High'
    elif month in ['September','October','November','April','May']:
        return 'Shoulder'
    elif month in ['December','January','February','March']:
        return 'Low'
    else:
        return 'Unidentified'

# %%
# Create new feature using the function 'month_to_season'
df['season'] = df['arrival_date_month'].apply(month_to_season)

# %%
# Display and count the unique values in 'season' column
df['season'].value_counts()
# Out:
# season
# Shoulder    51136
# High        37405
# Low         30350
# Name: count, dtype: int64

# %%
# Drop the feature 'arrival_date_month'
df = df.drop('arrival_date_month',axis = 1)

# %% [markdown]
# ### Outliers

# %%
df.describe().T
# Out:
#                                    count        mean         std   min   25%  \
# lead_time                       118891.0  104.314877  106.905191  0.00  18.0
# arrival_date_week_number        118891.0   27.166312   13.589783  1.00  16.0
# arrival_date_day_of_month       118891.0   15.801019    8.780356  1.00   8.0
# stays_in_weekend_nights         118891.0    0.928893    0.996228  0.00   0.0
# stays_in_week_nights            118891.0    2.502199    1.900198  0.00   1.0
# adults                          118891.0    1.858391    0.578572  0.00   2.0
# children                        118891.0    0.104196    0.399146  0.00   0.0
# babies                          118891.0    0.007948    0.097383  0.00   0.0
# previous_cancellations          118891.0    0.087147    0.845894  0.00   0.0
# previous_bookings_not_canceled  118891.0    0.131642    1.484715  0.00   0.0
# booking_changes                 118891.0    0.221186    0.652798  0.00   0.0
# days_in_waiting_list            118891.0    2.330891   17.630962  0.00   0.0
# adr                             118891.0  102.000739   50.485331 -6.38  70.0
# required_car_parking_spaces     118891.0    0.061880    0.244164  0.00   0.0
# total_of_special_requests       118891.0    0.571641    0.792643  0.00   0.0
# meal_ordinal                    118891.0    1.035570    0.496235  0.00   1.0
#
#                                  50%    75%     max
# lead_time                       69.0  161.0   737.0
# arrival_date_week_number        28.0   38.0    53.0
# arrival_date_day_of_month       16.0   23.0    31.0
# stays_in_weekend_nights          1.0    2.0    16.0
# stays_in_week_nights             2.0    3.0    41.0
# adults                           2.0    2.0    55.0
# children                         0.0    0.0    10.0
# babies                           0.0    0.0    10.0
# previous_cancellations           0.0    0.0    26.0
# previous_bookings_not_canceled   0.0    0.0    72.0
# booking_changes                  0.0    0.0    21.0
# days_in_waiting_list             0.0    0.0   391.0
# adr                             95.0  126.0  5400.0
# required_car_parking_spaces      0.0    0.0     8.0
# total_of_special_requests        0.0    1.0     5.0
# meal_ordinal                     1.0    1.0     3.0

# %%
df[df['adr'] >1000]
# Out:
#             hotel  is_canceled  lead_time arrival_date_year  \
# 48515  City Hotel         True         35              2016
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 48515                        13                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 48515                        0                     1       2       0.0
#
#        babies market_segment distribution_channel  is_repeated_guest  \
# 48515       0  Offline TA/TO                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 48515                       0                               0
#
#        booking_changes deposit_type  days_in_waiting_list customer_type  \
# 48515                1   Non Refund                     0     Transient
#
#           adr  required_car_parking_spaces  total_of_special_requests  \
# 48515  5400.0                            0                          0
#
#       continent  is_room_type_matched  meal_ordinal season
# 48515        EU                  True             1    Low

# %%
df.shape
# Out:
# (118891, 27)

# %%
df = df.drop(df[df['adr']>1000].index)

# %%
df.shape
# Out:
# (118890, 27)

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ### Encoding Categorical Variables

# %%
df.describe(include='object').T
# Out:
#                        count unique         top    freq
# hotel                 118890      2  City Hotel   79294
# arrival_date_year     118890      3        2016   56431
# market_segment        118890      7   Online TA   56396
# distribution_channel  118890      5       TA/TO   97723
# deposit_type          118890      3  No Deposit  104156
# customer_type         118890      4   Transient   89166
# continent             118890      6          EU  107821
# season                118890      3    Shoulder   51136

# %% [markdown]
# ### Nominal Features

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
lstt = ['hotel','arrival_date_year','market_segment','distribution_channel','deposit_type','customer_type','continent','season']

# %%
encoder = OneHotEncoder(categories = 'auto',
                       sparse_output = False, drop= 'if_binary')
encoded = encoder.fit(df[['hotel','arrival_date_year','market_segment','distribution_channel','deposit_type','customer_type','continent','season']])

# %%
encoded.categories_
# Out:
# [array(['City Hotel', 'Resort Hotel'], dtype=object),
#  array([2015, 2016, 2017], dtype=object),
#  array(['Aviation', 'Complementary', 'Corporate', 'Direct', 'Groups',
#         'Offline TA/TO', 'Online TA'], dtype=object),
#  array(['Corporate', 'Direct', 'GDS', 'TA/TO', 'Undefined'], dtype=object),
#  array(['No Deposit', 'Non Refund', 'Refundable'], dtype=object),
#  array(['Contract', 'Group', 'Transient', 'Transient-Party'], dtype=object),
#  array(['AF', 'AS', 'EU', 'NA', 'OC', 'SA'], dtype=object),
#  array(['High', 'Low', 'Shoulder'], dtype=object)]

# %%
array_encoded = encoded.transform(df[['hotel','arrival_date_year','market_segment','distribution_channel','deposit_type','customer_type','continent','season']])

# %%
df_encoded = pd.DataFrame(data = array_encoded, columns = encoded.get_feature_names_out(), dtype = 'bool')

# %%
df_encoded.head()
# Out:
#    hotel_Resort Hotel  arrival_date_year_2015  arrival_date_year_2016  \
# 0                True                    True                   False
# 1                True                    True                   False
# 2                True                    True                   False
# 3                True                    True                   False
# 4                True                    True                   False
#
#    arrival_date_year_2017  market_segment_Aviation  \
# 0                   False                    False
# 1                   False                    False
# 2                   False                    False
# 3                   False                    False
# 4                   False                    False
#
#    market_segment_Complementary  market_segment_Corporate  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                      True
# 4                         False                     False
#
#    market_segment_Direct  market_segment_Groups  market_segment_Offline TA/TO  \
# 0                   True                  False                         False
# 1                   True                  False                         False
# 2                   True                  False                         False
# 3                  False                  False                         False
# 4                  False                  False                         False
#
#    market_segment_Online TA  distribution_channel_Corporate  \
# 0                     False                           False
# 1                     False                           False
# 2                     False                           False
# 3                     False                            True
# 4                      True                           False
#
#    distribution_channel_Direct  distribution_channel_GDS  \
# 0                         True                     False
# 1                         True                     False
# 2                         True                     False
# 3                        False                     False
# 4                        False                     False
#
#    distribution_channel_TA/TO  distribution_channel_Undefined  \
# 0                       False                           False
# 1                       False                           False
# 2                       False                           False
# 3                       False                           False
# 4                        True                           False
#
#    deposit_type_No Deposit  deposit_type_Non Refund  deposit_type_Refundable  \
# 0                     True                    False                    False
# 1                     True                    False                    False
# 2                     True                    False                    False
# 3                     True                    False                    False
# 4                     True                    False                    False
#
#    customer_type_Contract  customer_type_Group  customer_type_Transient  \
# 0                   False                False                     True
# 1                   False                False                     True
# 2                   False                False                     True
# 3                   False                False                     True
# 4                   False                False                     True
#
#    customer_type_Transient-Party  continent_AF  continent_AS  continent_EU  \
# 0                          False         False         False          True
# 1                          False         False         False          True
# 2                          False         False         False          True
# 3                          False         False         False          True
# 4                          False         False         False          True
#
#    continent_NA  continent_OC  continent_SA  season_High  season_Low  \
# 0         False         False         False         True       False
# 1         False         False         False         True       False
# 2         False         False         False         True       False
# 3         False         False         False         True       False
# 4         False         False         False         True       False
#
#    season_Shoulder
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
df_encoded.shape
# Out:
# (118890, 32)

# %%
df.shape
# Out:
# (118890, 27)

# %%
df_merged = df.merge(df_encoded, left_index=True, right_index=True, validate='one_to_one')

# %%
df_merged.shape
# Out:
# (118890, 59)

# %%
df_merged = df_merged.drop(['hotel','arrival_date_year','market_segment','distribution_channel','deposit_type','customer_type','continent','season'], axis=1)

# %%
df_merged.shape
# Out:
# (118890, 51)

# %%
import numpy as np

# %%
df_merged.describe(include= np.number).T
# Out:
#                                    count        mean         std   min   25%  \
# lead_time                       118890.0  104.315460  106.905451  0.00  18.0
# arrival_date_week_number        118890.0   27.166431   13.589778  1.00  16.0
# arrival_date_day_of_month       118890.0   15.800942    8.780353  1.00   8.0
# stays_in_weekend_nights         118890.0    0.928901    0.996229  0.00   0.0
# stays_in_week_nights            118890.0    2.502212    1.900201  0.00   1.0
# adults                          118890.0    1.858390    0.578574  0.00   2.0
# children                        118890.0    0.104197    0.399147  0.00   0.0
# babies                          118890.0    0.007949    0.097383  0.00   0.0
# previous_cancellations          118890.0    0.087148    0.845897  0.00   0.0
# previous_bookings_not_canceled  118890.0    0.131643    1.484721  0.00   0.0
# booking_changes                 118890.0    0.221179    0.652797  0.00   0.0
# days_in_waiting_list            118890.0    2.330911   17.631035  0.00   0.0
# adr                             118890.0  101.956177   48.090494 -6.38  70.0
# required_car_parking_spaces     118890.0    0.061881    0.244165  0.00   0.0
# total_of_special_requests       118890.0    0.571646    0.792645  0.00   0.0
# meal_ordinal                    118890.0    1.035571    0.496237  0.00   1.0
#
#                                  50%    75%    max
# lead_time                       69.0  161.0  737.0
# arrival_date_week_number        28.0   38.0   53.0
# arrival_date_day_of_month       16.0   23.0   31.0
# stays_in_weekend_nights          1.0    2.0   16.0
# stays_in_week_nights             2.0    3.0   41.0
# adults                           2.0    2.0   55.0
# children                         0.0    0.0   10.0
# babies                           0.0    0.0   10.0
# previous_cancellations           0.0    0.0   26.0
# previous_bookings_not_canceled   0.0    0.0   72.0
# booking_changes                  0.0    0.0   21.0
# days_in_waiting_list             0.0    0.0  391.0
# adr                             95.0  126.0  510.0
# required_car_parking_spaces      0.0    0.0    8.0
# total_of_special_requests        0.0    1.0    5.0
# meal_ordinal                     1.0    1.0    3.0

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118890 entries, 0 to 118889
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   is_canceled                     118890 non-null  bool
#  1   lead_time                       118890 non-null  int64
#  2   arrival_date_week_number        118890 non-null  int64
#  3   arrival_date_day_of_month       118890 non-null  int64
#  4   stays_in_weekend_nights         118890 non-null  int64
#  5   stays_in_week_nights            118890 non-null  int64
#  6   adults                          118890 non-null  int64
#  7   children                        118890 non-null  float64
#  8   babies                          118890 non-null  int64
#  9   is_repeated_guest               118890 non-null  bool
#  10  previous_cancellations          118890 non-null  int64
#  11  previous_bookings_not_canceled  118890 non-null  int64
#  12  booking_changes                 118890 non-null  int64
#  13  days_in_waiting_list            118890 non-null  int64
#  14  adr                             118890 non-null  float64
#  15  required_car_parking_spaces     118890 non-null  int64
#  16  total_of_special_requests       118890 non-null  int64
#  17  is_room_type_matched            118890 non-null  bool
#  18  meal_ordinal                    118890 non-null  int64
#  19  hotel_Resort Hotel              118890 non-null  bool
#  20  arrival_date_year_2015          118890 non-null  bool
#  21  arrival_date_year_2016          118890 non-null  bool
#  22  arrival_date_year_2017          118890 non-null  bool
#  23  market_segment_Aviation         118890 non-null  bool
#  24  market_segment_Complementary    118890 non-null  bool
#  25  market_segment_Corporate        118890 non-null  bool
#  26  market_segment_Direct           118890 non-null  bool
#  27  market_segment_Groups           118890 non-null  bool
#  28  market_segment_Offline TA/TO    118890 non-null  bool
#  29  market_segment_Online TA        118890 non-null  bool
#  30  distribution_channel_Corporate  118890 non-null  bool
#  31  distribution_channel_Direct     118890 non-null  bool
#  32  distribution_channel_GDS        118890 non-null  bool
#  33  distribution_channel_TA/TO      118890 non-null  bool
#  34  distribution_channel_Undefined  118890 non-null  bool
#  35  deposit_type_No Deposit         118890 non-null  bool
#  36  deposit_type_Non Refund         118890 non-null  bool
#  37  deposit_type_Refundable         118890 non-null  bool
#  38  customer_type_Contract          118890 non-null  bool
#  39  customer_type_Group             118890 non-null  bool
#  40  customer_type_Transient         118890 non-null  bool
#  41  customer_type_Transient-Party   118890 non-null  bool
#  42  continent_AF                    118890 non-null  bool
#  43  continent_AS                    118890 non-null  bool
#  44  continent_EU                    118890 non-null  bool
#  45  continent_NA                    118890 non-null  bool
#  46  continent_OC                    118890 non-null  bool
#  47  continent_SA                    118890 non-null  bool
#  48  season_High                     118890 non-null  bool
#  49  season_Low                      118890 non-null  bool
#  50  season_Shoulder                 118890 non-null  bool
# dtypes: bool(35), float64(2), int64(14)
# memory usage: 18.5 MB

# %% [markdown]
# ### Splitting the Dataset

# %%
X = df_merged.drop('is_canceled',axis=1)
y = df_merged['is_canceled']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (95112, 50) (23778, 50) (95112,) (23778,)

# %% [markdown]
# #### Scaling the Dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
num_cols = X_train.columns[(X_train.dtypes == 'int64') | (X_train.dtypes == 'float64')].tolist()

# %%
num_cols
# Out:
# ['lead_time',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'meal_ordinal']

# %%
X_train_scaled = X_train.copy()
X_train_scaled[num_cols] = scaler.fit_transform(X_train[num_cols])

# %%
X_test_scaled = X_test.copy()
X_test_scaled[num_cols] = scaler.fit_transform(X_test[num_cols])

# %% [markdown]
# ## Creating the Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(random_state=99, solver = 'sag')
model = lr.fit(X_train_scaled, y_train)

# %%
type(model)
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %%
predictions = model.predict(X_test_scaled)

# %%
X_test_scaled['prediction'] = predictions
X_test_scaled['label'] = y_test

# %%
X_test_scaled.head()
# Out:
#         lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 85995    0.074722                  0.250000                   0.000000
# 21939    0.022258                  0.211538                   0.600000
# 107362   0.073132                  0.192308                   0.466667
# 109430   0.165342                  0.269231                   0.433333
# 97475    0.000000                  0.730769                   0.700000
#
#         stays_in_weekend_nights  stays_in_week_nights    adults  children  \
# 85995                  0.111111              0.083333  0.074074       0.0
# 21939                  0.222222              0.125000  0.074074       0.0
# 107362                 0.000000              0.166667  0.074074       0.0
# 109430                 0.222222              0.125000  0.074074       0.0
# 97475                  0.000000              0.041667  0.037037       0.0
#
#         babies  is_repeated_guest  previous_cancellations  \
# 85995      0.0              False                     0.0
# 21939      0.0              False                     0.0
# 107362     0.0              False                     0.0
# 109430     0.0              False                     0.0
# 97475      0.0              False                     0.0
#
#         previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 85995                              0.0         0.000000                   0.0
# 21939                              0.0         0.058824                   0.0
# 107362                             0.0         0.000000                   0.0
# 109430                             0.0         0.000000                   0.0
# 97475                              0.0         0.000000                   0.0
#
#              adr  required_car_parking_spaces  total_of_special_requests  \
# 85995   0.209055                          0.0                        0.0
# 21939   0.114173                          0.0                        0.0
# 107362  0.247638                          0.0                        0.4
# 109430  0.281693                          0.0                        0.2
# 97475   0.374016                          0.0                        0.4
#
#         is_room_type_matched  meal_ordinal  hotel_Resort Hotel  \
# 85995                   True      0.333333               False
# 21939                   True      0.000000                True
# 107362                 False      0.333333               False
# 109430                  True      0.333333               False
# 97475                   True      0.333333               False
#
#         arrival_date_year_2015  arrival_date_year_2016  \
# 85995                    False                    True
# 21939                    False                    True
# 107362                   False                   False
# 109430                   False                   False
# 97475                    False                    True
#
#         arrival_date_year_2017  market_segment_Aviation  \
# 85995                    False                    False
# 21939                    False                    False
# 107362                    True                    False
# 109430                    True                    False
# 97475                    False                    False
#
#         market_segment_Complementary  market_segment_Corporate  \
# 85995                          False                     False
# 21939                          False                     False
# 107362                         False                     False
# 109430                         False                     False
# 97475                          False                     False
#
#         market_segment_Direct  market_segment_Groups  \
# 85995                   False                  False
# 21939                   False                  False
# 107362                  False                  False
# 109430                  False                  False
# 97475                   False                  False
#
#         market_segment_Offline TA/TO  market_segment_Online TA  \
# 85995                          False                      True
# 21939                           True                     False
# 107362                         False                      True
# 109430                         False                      True
# 97475                          False                      True
#
#         distribution_channel_Corporate  distribution_channel_Direct  \
# 85995                            False                        False
# 21939                            False                        False
# 107362                           False                        False
# 109430                           False                        False
# 97475                            False                        False
#
#         distribution_channel_GDS  distribution_channel_TA/TO  \
# 85995                      False                        True
# 21939                      False                        True
# 107362                     False                        True
# 109430                     False                        True
# 97475                      False                        True
#
#         distribution_channel_Undefined  deposit_type_No Deposit  \
# 85995                            False                     True
# 21939                            False                     True
# 107362                           False                     True
# 109430                           False                     True
# 97475                            False                     True
#
#         deposit_type_Non Refund  deposit_type_Refundable  \
# 85995                     False                    False
# 21939                     False                    False
# 107362                    False                    False
# 109430                    False                    False
# 97475                     False                    False
#
#         customer_type_Contract  customer_type_Group  customer_type_Transient  \
# 85995                    False                False                     True
# 21939                    False                False                     True
# 107362                   False                False                     True
# 109430                   False                False                     True
# 97475                    False                False                     True
#
#         customer_type_Transient-Party  continent_AF  continent_AS  \
# 85995                           False         False         False
# 21939                           False         False         False
# 107362                          False         False         False
# 109430                          False         False         False
# 97475                           False         False         False
#
#         continent_EU  continent_NA  continent_OC  continent_SA  season_High  \
# 85995           True         False         False         False        False
# 21939           True         False         False         False        False
# 107362          True         False         False         False        False
# 109430          True         False         False         False        False
# 97475           True         False         False         False        False
#
#         season_Low  season_Shoulder  prediction  label
# 85995        False             True        True  False
# 21939         True            False       False  False
# 107362        True            False       False  False
# 109430       False             True        True  False
# 97475        False             True       False  False

# %%
from sklearn.metrics import f1_score, accuracy_score, recall_score

# %%
f1_score(X_test_scaled['label'],X_test_scaled['prediction'])
# Out:
# 0.7158941190561744

# %%
accuracy_score(X_test_scaled['label'],X_test_scaled['prediction'])
# Out:
# 0.8004878459079822

# %%
recall_score(X_test_scaled['label'],X_test_scaled['prediction'])
# Out:
# 0.6838672768878719
